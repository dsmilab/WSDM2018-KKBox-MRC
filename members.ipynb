# %%
import seaborn as sns
import pandas as pd
import numpy as np
import lightgbm as lgb
import matplotlib.pyplot as plt
import datetime as dt

import gc

MODEL_FILE_NAME = 'model.txt'

# %%
members_df = pd.read_csv('data/members.csv')
members_df.info()
members_df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34403 entries, 0 to 34402
# Data columns (total 7 columns):
# msno                      34403 non-null object
# city                      34403 non-null int64
# bd                        34403 non-null int64
# gender                    14501 non-null object
# registered_via            34403 non-null int64
# registration_init_time    34403 non-null int64
# expiration_date           34403 non-null int64
# dtypes: int64(5), object(2)
# memory usage: 1.8+ MB
#                                             msno  city  bd  gender  \
# 0   XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0     NaN
# 1   UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0     NaN
# 2   D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0     NaN
# 3   mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0     NaN
# 4   q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0     NaN
# 5   zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=    13  43  female
# 6   Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=     1   0     NaN
# 7   pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=     1   0     NaN
# 8   kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=     1   0     NaN
# 9   tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=     1   0     NaN
# 10  GoFYKhcq8Q5Gjz1M5L0azHZOhcY+Za/T7fRqIGgBuYA=    12  28    male
# 11  Hiw71XZQSoEe1I7pBhPWi3kIrP7Ss7pwExZgtqFmtYw=     1   0     NaN
# 12  V6QgFYHgsfZ2G6hFz1z2u3RrLt5BoLsZKBr+h0ZnFsA=     1   0     NaN
# 13  RoSfblbwJN/izEnFIVw8TgOpm8R/NEpUC84Oz/b32HQ=    15  33  female
# 14  N+dxmo1qvkKAlzYtcxGzjrqcpVyX9J7AMlXFuYASKuY=     1   0     NaN
#
#     registered_via  registration_init_time  expiration_date
# 0                7                20110820         20170920
# 1                7                20150628         20170622
# 2                4                20160411         20170712
# 3                9                20150906         20150907
# 4                4                20170126         20170613
# 5                9                20120703         20171006
# 6                4                20160326         20160329
# 7                7                20160130         20170930
# 8                7                20110111         20170930
# 9                7                20160217         20170613
# 10               9                20060531         20170816
# 11               7                20150909         20170909
# 12               7                20120105         20170918
# 13               3                20150915         20171019
# 14               3                20140412         20170815

# %%
def parse_str_to_date(date_str):
    # [format] yyyymmdd
    date_str = str(date_str)
    assert(isinstance(date_str, str))
    assert(len(date_str) == 8)
    
    year = int(date_str[:4])
    month = int(date_str[4:6])
    day = int(date_str[6:])
    
    return dt.date(year, month, day)
    
           
def transform_two_dates_to_days(row):
    start = parse_str_to_date(row['registration_init_time'])
    end = parse_str_to_date(row['expiration_date'])
    delta = end - start
    
    return delta.days


members_df['membership_days'] = members_df.apply(transform_two_dates_to_days, axis=1)
members_df.drop(['registration_init_time', 'expiration_date', 'bd', 'gender'], axis=1, inplace=True)
members_df
# Out:
#                                                msno  city  registered_via  \
# 0      XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1               7
# 1      UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1               7
# 2      D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1               4
# 3      mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1               9
# 4      q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     
# 34381  RzhTfn+9ZL/agg3KU+w3OV771vPZBdME/zVw8L+JqE4=    22               9
# 34382  h+y94tam2umL5tkLQ2Bb7e7KZkrvAn0VYTi0T8VfJZA=     6               3
# 34383  cZnVSva/eyG76AnN5FVhcd3E6rDlxZYodHmoNmL5jRI=     1               7
# 34384  mZv23MYsFZN0pupsxqlHCUFqNgZPw/4osbyJkei/SRA=    15               9
# 34385  gvPKk3epmZYeBHTsfhss+QnaeR1yLQbsZMvw1WcWuFg=     1               7
# 34386  w9cnrfPt9BJZXB2qCjuneN+9gJZ1rXxrCR6lpazzZn0=     1               7
# 34387  Hm+tHiwBnztX5L6FORYQI6Qr8bCUc7P276HQWganPwg=     9               9
# 34388  V64FfynlRd8b7s76Lga3I2M9pJXc16jQi3TyedJNNTU=    21               3
# 34389  38pbfUNqxyF3kAQ5Ops549OfoCa3vVAbryBlyQ5fElA=     4               3
# 34390  buUH+5Pt7Oe5MRJmHzAoaGqApNIlepdLtMPbaYRLsF8=    12               7
# 34391  Lhhn8qbJj1UojqarOLrSI0RLb+llCBYi3qsdYWK31WA=     1               4
# 34392  MztOLNMRfOazE4FOBfQPUAoCSkaXJzI/42gRSwm0+hE=    22               9
# 34393  b2sH2FEdfr+2iyi3FlbQ3aMQwSmx/Mu0QLQHy7PinLA=     4               9
# 34394  gwRDIcbF3glSxxzs0ReSAhL5qezHN2Z4MMr29IBxeDo=    18               9
# 34395  Azz7DTejzI4MPY2+mLnzDu8GcN/gdoBkC4ncxx+Y+Ss=     1               9
# 34396  UUpdbYb6xeTNAt7dz8EQ7MNOpwH+gk9jMpIx5Hh/WI0=    13               3
# 34397  9atvTKXo3kVao2jCDpsRDBmwXEMREmDTj3o9BQWEDQk=    15               3
# 34398  Wwd/cudKVuLJ3txRVxlg2Zaeliu+LRUfiBmfrnxhRCY=     1               7
# 34399  g3JGnJX6Hg50lFbrNWfsHwCUmApIkiv2M8sXOaeXoIQ=     4               3
# 34400  IMaPMJuyN+ip9Vqi+z2XuXbFAP2kbHr+EvvCNkFfj+o=     1               7
# 34401  WAnCAJjUty9Stv8yKtV7ZC7PN+ilOy5FX3aIJgGPANM=     1               7
# 34402  xH8KpzKGeNNq6dOvy51c/8VzqOiGG+m6vabhsPSDHX4=     1               4
#
#        membership_days
# 0                 2223
# 1                  725
# 2                  457
# 3                    1
# 4                  138
# 5                 1921
# 6                    3
# 7                  609
# 8                 2454
# 9                  482
# 10                4095
# 11                 731
# 12                2083
# 13                 765
# 14                1221
# 15                1113
# 16                3727
# 17                1737
# 18                 172
# 19                 367
# 20                   3
# 21                 257
# 22                   3
# 23                 200
# 24                   3
# 25                 289
# 26                   3
# 27                1335
# 28                1338
# 29                   7
# ...                ...
# 34373              596
# 34374             2217
# 34375                3
# 34376              851
# 34377              829
# 34378             3819
# 34379             2360
# 34380              477
# 34381             2286
# 34382              807
# 34383              337
# 34384             1437
# 34385              728
# 34386             1450
# 34387             1665
# 34388             1296
# 34389             1360
# 34390             1613
# 34391                3
# 34392             2938
# 34393              813
# 34394             3500
# 34395              725
# 34396             1985
# 34397             1653
# 34398             1399
# 34399              937
# 34400             1498
# 34401              701
# 34402                3
#
# [34403 rows x 4 columns]
